# %% [markdown]
# <a href="https://colab.research.google.com/github/Panachai-spec007/BSC_DPDM2025/blob/main/Ch3_Data_Preprocessing.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Import data

# %%
import pandas as pd

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
flood = pd.read_csv('/content/drive/MyDrive/GreenFN/BSC_DPDM2025/flooding database.csv')
flood.head()
# Out:
#                          system:index  index threshold_type glide_index  \
# 0  DFO_1586_From_20000218_to_20000301   1586           otsu           0
# 1  DFO_1587_From_20000217_to_20000311   1587           otsu           0
# 2  DFO_1595_From_20000405_to_20000425   1595           otsu           0
# 3  DFO_1614_From_20000711_to_20000810   1614           otsu           0
# 4  DFO_1627_From_20000830_to_20000910   1627           otsu           0
#
#   dfo_country dfo_other_country  dfo_centroid_x  dfo_centroid_y dfo_began  \
# 0   Australia                 0      143.697800      -31.268059   2/18/00
# 1  Madagascar                 0       47.295670      -15.782624   2/17/00
# 2     Romania           Hungary       22.415404       46.763746    4/5/00
# 3    Thailand           Vietnam      105.063841       11.242567   7/11/00
# 4       China            Russia      132.057679       43.773883   8/30/00
#
#   dfo_ended  ...              dfo_cause  dfo_severity  gfd_area  \
# 0    3/1/00  ...             Heavy rain           2.0    316.73
# 1   3/11/00  ...  Tropical Storm, Surge           1.0    228.50
# 2   4/25/00  ...    Snowmelt, Ice, Rain           2.0     89.10
# 3   8/10/00  ...             Heavy rain           1.0   4322.47
# 4   9/10/00  ...  Tropical Storm, Surge           1.0    740.33
#
#   gfd_exp_ghsl_ts  gfd_exp_ghsl_2000  gfd_exp_ghsl_2015  Errors  dif 2000  \
# 0            38.0               38.0                 43       1         0
# 1          4594.0             4594.0               6855       1         0
# 2          3093.0             3093.0               4618       1         0
# 3        544758.0           544758.0             658643       1         0
# 4        785363.0           785363.0             766309       1         0
#
#    dif 2015  error 2000
# 0        -5         NaN
# 1     -2261         NaN
# 2     -1525         NaN
# 3   -113885         NaN
# 4     19054         1.0
#
# [5 rows x 23 columns]

# %% [markdown]
# # Data Cleaning

# %% [markdown]
# ## Missing Data

# %% [markdown]
# ### Check Missing

# %%
flood.shape
# Out:
# (913, 23)

# %%
flood.isnull().sum()
# Out:
# system:index           0
# index                  0
# threshold_type         0
# glide_index          232
# dfo_country            0
# dfo_other_country    275
# dfo_centroid_x         0
# dfo_centroid_y         0
# dfo_began              0
# dfo_ended              1
# dfo_validation         2
# dfo_dead               0
# dfo_displaced          0
# dfo_cause              2
# dfo_severity           0
# gfd_area               0
# gfd_exp_ghsl_ts        1
# gfd_exp_ghsl_2000      1
# gfd_exp_ghsl_2015      0
# Errors                 0
# dif 2000               0
# dif 2015               0
# error 2000           889
# dtype: int64

# %% [markdown]
# ### Drop Record ที่มี missing ออก

# %%
flood_drop = flood.dropna()
flood_drop.shape
# Out:
# (13, 23)

# %% [markdown]
# Drop ถ้ามี missing

# %% [markdown]
# Drob เฉพาะเกิด missing ในตัวแปรที่เราจะใช้
#
# -dfo_country
#
# -dfo_other_country
#
# -dfo_began
#
# -dfo_ended
#
# -dfo_dead
#
# -dfo_cause
#
# -dfo_severity

# %%
flood_drop2 = flood.dropna(subset=['dfo_country','dfo_other_country','dfo_began','dfo_ended','dfo_dead','dfo_cause','dfo_severity'])
flood_drop2.shape
# Out:
# (637, 23)

# %% [markdown]
# ### เติม Dummy

# %%
flood[flood.isnull()['dfo_other_country']]
# Out:
#                            system:index  index threshold_type  \
# 172  DFO_2415_From_20040110_to_20040119   2415            std
# 383  DFO_3089_From_20070530_to_20070603   3089            std
# 387  DFO_3097_From_20070611_to_20070624   3097            std
# 412  DFO_3136_From_20070721_to_20071015   3136            std
# 428  DFO_3166_From_20070726_to_20071010   3166            std
# ..                                  ...    ...            ...
# 908  DFO_4683_From_20180901_to_20181002   4683            std
# 909  DFO_4695_From_20181023_to_20181027   4695            std
# 910  DFO_4703_From_20181029_to_20181107   4703           otsu
# 911  DFO_4704_From_20181124_to_20181129   4704            std
# 912  DFO_4711_From_20181205_to_20181210   4711            std
#
#             glide_index         dfo_country dfo_other_country  dfo_centroid_x  \
# 172                   0                Iran               NaN       51.439491
# 383                   0  Dominican Republic               NaN      -71.053795
# 387  LS-2007-000080-BGD          Bangladesh               NaN       91.953546
# 412                   0          Bangladesh               NaN       91.233643
# 428  FL-2007-000132-BFA               Ghana               NaN        0.612005
# ..                  ...                 ...               ...             ...
# 908                 NaN               Ghana               NaN       -1.066060
# 909                 NaN              Mexico               NaN     -105.236000
# 910                 NaN            Paraguay               NaN      -57.085300
# 911                 NaN             Vietnam               NaN      107.137000
# 912                 NaN                 USA               NaN     -120.058000
#
#      dfo_centroid_y dfo_began dfo_ended  ...              dfo_cause  \
# 172       29.466641   1/10/04   1/19/04  ...             Heavy rain
# 383       19.547861   5/30/07    6/3/07  ...             Heavy rain
# 387       22.397464   6/11/07   6/24/07  ...             Heavy rain
# 412       23.916419   7/21/07  10/15/07  ...             Heavy rain
# 428       13.037658   7/26/07  10/10/07  ...             Heavy rain
# ..              ...       ...       ...  ...                    ...
# 908        9.537550    9/1/18   10/2/18  ...                    Dam
# 909       23.721800  10/23/18  10/27/18  ...  Tropical Storm, Surge
# 910      -25.342700  10/29/18   11/7/18  ...             Heavy rain
# 911       11.491000  11/24/18  11/29/18  ...  Tropical Storm, Surge
# 912       35.778700   12/5/18  12/10/18  ...             Heavy rain
#
#      dfo_severity  gfd_area gfd_exp_ghsl_ts  gfd_exp_ghsl_2000  \
# 172           1.0   7017.61         23986.0            23986.0
# 383           1.0    100.92         13819.0            13819.0
# 387           1.0  20493.38       4536692.0          4536692.0
# 412           1.0  78785.53      27712991.0         27712998.0
# 428           1.5   7621.96        325408.0           325408.0
# ..            ...       ...             ...                ...
# 908           1.5   1866.91         79032.0            38895.0
# 909           1.5   2720.37         23128.0            15725.0
# 910           1.0  10019.87         29435.0            25393.0
# 911           1.0   6467.41        218916.0           173753.0
# 912           1.5   2475.92         28821.0            26654.0
#
#      gfd_exp_ghsl_2015  Errors  dif 2000  dif 2015  error 2000
# 172             116060       1         0    -92074         NaN
# 383              11672       1         0      2147         NaN
# 387            8995159       1         0  -4458467         NaN
# 412           55288622       0        -7 -27575631         NaN
# 428             624312       1         0   -298904         NaN
# ..                 ...     ...       ...       ...         ...
# 908              79032       1     40137         0         NaN
# 909              23128       1      7403         0         NaN
# 910              29435       1      4042         0         NaN
# 911             218915       0     45163         1         NaN
# 912              28821       1      2167         0         NaN
#
# [275 rows x 23 columns]

# %%
flood_filldummy = flood.fillna(value={'dfo_other_country':'Unknown'})
flood_filldummy.isnull().sum()
# Out:
# system:index           0
# index                  0
# threshold_type         0
# glide_index          232
# dfo_country            0
# dfo_other_country      0
# dfo_centroid_x         0
# dfo_centroid_y         0
# dfo_began              0
# dfo_ended              1
# dfo_validation         2
# dfo_dead               0
# dfo_displaced          0
# dfo_cause              2
# dfo_severity           0
# gfd_area               0
# gfd_exp_ghsl_ts        1
# gfd_exp_ghsl_2000      1
# gfd_exp_ghsl_2015      0
# Errors                 0
# dif 2000               0
# dif 2015               0
# error 2000           889
# dtype: int64

# %% [markdown]
# ### เติม missing ด้วยค่ากลาง

# %%
flood.groupby('dfo_cause').count()
# Out:
#                        system:index  index  threshold_type  glide_index  \
# dfo_cause
# Dam                              13     13              13           11
# Heavy rain                      749    749             749          554
# Snowmelt, Ice, Rain              52     52              52           45
# Tropical Storm, Surge            97     97              97           71
#
#                        dfo_country  dfo_other_country  dfo_centroid_x  \
# dfo_cause
# Dam                             13                 10              13
# Heavy rain                     749                530             749
# Snowmelt, Ice, Rain             52                 45              52
# Tropical Storm, Surge           97                 53              97
#
#                        dfo_centroid_y  dfo_began  dfo_ended  ...  \
# dfo_cause                                                    ...
# Dam                                13         13         13  ...
# Heavy rain                        749        749        748  ...
# Snowmelt, Ice, Rain                52         52         52  ...
# Tropical Storm, Surge              97         97         97  ...
#
#                        dfo_displaced  dfo_severity  gfd_area  gfd_exp_ghsl_ts  \
# dfo_cause
# Dam                               13            13        13               13
# Heavy rain                       749           749       749              748
# Snowmelt, Ice, Rain               52            52        52               52
# Tropical Storm, Surge             97            97        97               97
#
#                        gfd_exp_ghsl_2000  gfd_exp_ghsl_2015  Errors  dif 2000  \
# dfo_cause
# Dam                                   13                 13      13        13
# Heavy rain                           748                749     749       749
# Snowmelt, Ice, Rain                   52                 52      52        52
# Tropical Storm, Surge                 97                 97      97        97
#
#                        dif 2015  error 2000
# dfo_cause
# Dam                          13           0
# Heavy rain                  749          16
# Snowmelt, Ice, Rain          52           7
# Tropical Storm, Surge        97           1
#
# [4 rows x 22 columns]

# %%
flood_fillmode = flood.fillna(value={'dfo_cause':'Heavy rain'})
flood_fillmode.isnull().sum()
# Out:
# system:index           0
# index                  0
# threshold_type         0
# glide_index          232
# dfo_country            0
# dfo_other_country    275
# dfo_centroid_x         0
# dfo_centroid_y         0
# dfo_began              0
# dfo_ended              1
# dfo_validation         2
# dfo_dead               0
# dfo_displaced          0
# dfo_cause              0
# dfo_severity           0
# gfd_area               0
# gfd_exp_ghsl_ts        1
# gfd_exp_ghsl_2000      1
# gfd_exp_ghsl_2015      0
# Errors                 0
# dif 2000               0
# dif 2015               0
# error 2000           889
# dtype: int64

# %% [markdown]
# ### เติมด้วยตัวแทนของกลุ่ม

# %%
flood.groupby(['dfo_severity', 'dfo_cause']).count()
# Out:
#                                     system:index  index  threshold_type  \
# dfo_severity dfo_cause
# 1.0          Dam                               9      9               9
#              Heavy rain                      464    464             464
#              Snowmelt, Ice, Rain              34     34              34
#              Tropical Storm, Surge            33     33              33
# 1.5          Dam                               3      3               3
#              Heavy rain                      163    163             163
#              Snowmelt, Ice, Rain               8      8               8
#              Tropical Storm, Surge            26     26              26
# 2.0          Dam                               1      1               1
#              Heavy rain                      122    122             122
#              Snowmelt, Ice, Rain              10     10              10
#              Tropical Storm, Surge            38     38              38
#
#                                     glide_index  dfo_country  \
# dfo_severity dfo_cause
# 1.0          Dam                              9            9
#              Heavy rain                     390          464
#              Snowmelt, Ice, Rain             29           34
#              Tropical Storm, Surge           32           33
# 1.5          Dam                              1            3
#              Heavy rain                      72          163
#              Snowmelt, Ice, Rain              7            8
#              Tropical Storm, Surge           12           26
# 2.0          Dam                              1            1
#              Heavy rain                      92          122
#              Snowmelt, Ice, Rain              9           10
#              Tropical Storm, Surge           27           38
#
#                                     dfo_other_country  dfo_centroid_x  \
# dfo_severity dfo_cause
# 1.0          Dam                                    9               9
#              Heavy rain                           369             464
#              Snowmelt, Ice, Rain                   30              34
#              Tropical Storm, Surge                 28              33
# 1.5          Dam                                    0               3
#              Heavy rain                            67             163
#              Snowmelt, Ice, Rain                    6               8
#              Tropical Storm, Surge                  7              26
# 2.0          Dam                                    1               1
#              Heavy rain                            94             122
#              Snowmelt, Ice, Rain                    9              10
#              Tropical Storm, Surge                 18              38
#
#                                     dfo_centroid_y  dfo_began  dfo_ended  ...  \
# dfo_severity dfo_cause                                                    ...
# 1.0          Dam                                 9          9          9  ...
#              Heavy rain                        464        464        463  ...
#              Snowmelt, Ice, Rain                34         34         34  ...
#              Tropical Storm, Surge              33         33         33  ...
# 1.5          Dam                                 3          3          3  ...
#              Heavy rain                        163        163        163  ...
#              Snowmelt, Ice, Rain                 8          8          8  ...
#              Tropical Storm, Surge              26         26         26  ...
# 2.0          Dam                                 1          1          1  ...
#              Heavy rain                        122        122        122  ...
#              Snowmelt, Ice, Rain                10         10         10  ...
#              Tropical Storm, Surge              38         38         38  ...
#
#                                     dfo_dead  dfo_displaced  gfd_area  \
# dfo_severity dfo_cause
# 1.0          Dam                           9              9         9
#              Heavy rain                  464            464       464
#              Snowmelt, Ice, Rain          34             34        34
#              Tropical Storm, Surge        33             33        33
# 1.5          Dam                           3              3         3
#              Heavy rain                  163            163       163
#              Snowmelt, Ice, Rain           8              8         8
#              Tropical Storm, Surge        26             26        26
# 2.0          Dam                           1              1         1
#              Heavy rain                  122            122       122
#              Snowmelt, Ice, Rain          10             10        10
#              Tropical Storm, Surge        38             38        38
#
#                                     gfd_exp_ghsl_ts  gfd_exp_ghsl_2000  \
# dfo_severity dfo_cause
# 1.0          Dam                                  9                  9
#              Heavy rain                         463                464
#              Snowmelt, Ice, Rain                 34                 34
#              Tropical Storm, Surge               33                 33
# 1.5          Dam                                  3                  3
#              Heavy rain                         163                162
#              Snowmelt, Ice, Rain                  8                  8
#              Tropical Storm, Surge               26                 26
# 2.0          Dam                                  1                  1
#              Heavy rain                         122                122
#              Snowmelt, Ice, Rain                 10                 10
#              Tropical Storm, Surge               38                 38
#
#                                     gfd_exp_ghsl_2015  Errors  dif 2000  \
# dfo_severity dfo_cause
# 1.0          Dam                                    9       9         9
#              Heavy rain                           464     464       464
#              Snowmelt, Ice, Rain                   34      34        34
#              Tropical Storm, Surge                 33      33        33
# 1.5          Dam                                    3       3         3
#              Heavy rain                           163     163       163
#              Snowmelt, Ice, Rain                    8       8         8
#              Tropical Storm, Surge                 26      26        26
# 2.0          Dam                                    1       1         1
#              Heavy rain                           122     122       122
#              Snowmelt, Ice, Rain                   10      10        10
#              Tropical Storm, Surge                 38      38        38
#
#                                     dif 2015  error 2000
# dfo_severity dfo_cause
# 1.0          Dam                           9           0
#              Heavy rain                  464           8
#              Snowmelt, Ice, Rain          34           6
#              Tropical Storm, Surge        33           1
# 1.5          Dam                           3           0
#              Heavy rain                  163           4
#              Snowmelt, Ice, Rain           8           0
#              Tropical Storm, Surge        26           0
# 2.0          Dam                           1           0
#              Heavy rain                  122           4
#              Snowmelt, Ice, Rain          10           1
#              Tropical Storm, Surge        38           0
#
# [12 rows x 21 columns]

# %%
flood_sever1 = flood[flood['dfo_severity'] == 1.0]
flood_sever15 = flood[flood['dfo_severity'] == 1.5]
flood_sever2 = flood[flood['dfo_severity'] == 2.0]

# %%
flood_sever1 = flood_sever1.fillna(value={'dfo_cause':'Heavy rain'})
flood_sever15 = flood_sever15.fillna(value={'dfo_cause':'Heavy rain'})
flood_sever2 = flood_sever2.fillna(value={'dfo_cause':'Tropical Strom,Surge'})

# %%
flood_fillgroup = pd.concat([flood_sever1,flood_sever15,flood_sever2])

# %%
flood_fillgroup.isnull().sum()
# Out:
# system:index           0
# index                  0
# threshold_type         0
# glide_index          232
# dfo_country            0
# dfo_other_country    275
# dfo_centroid_x         0
# dfo_centroid_y         0
# dfo_began              0
# dfo_ended              1
# dfo_validation         2
# dfo_dead               0
# dfo_displaced          0
# dfo_cause              0
# dfo_severity           0
# gfd_area               0
# gfd_exp_ghsl_ts        1
# gfd_exp_ghsl_2000      1
# gfd_exp_ghsl_2015      0
# Errors                 0
# dif 2000               0
# dif 2015               0
# error 2000           889
# dtype: int64

# %% [markdown]
# ## Noisy Data

# %% [markdown]
# Explor data

# %%
flood["gfd_area"]
# Out:
# 0        316.73
# 1        228.50
# 2         89.10
# 3       4322.47
# 4        740.33
#          ...
# 908     1866.91
# 909     2720.37
# 910    10019.87
# 911     6467.41
# 912     2475.92
# Name: gfd_area, Length: 913, dtype: float64

# %% [markdown]
# plot data

# %%
from matplotlib import pyplot as plt

# %%
plt.plot(flood["gfd_area"])

# %% [markdown]
# ใช้ histogram ดู Bin ที่เหมาะสม

# %%
outputhist = plt.hist(flood["gfd_area"],30);

# %%
outputhist[1]
# Out:
# array([    0.        ,  3284.92066667,  6569.84133333,  9854.762     ,
#        13139.68266667, 16424.60333333, 19709.524     , 22994.44466667,
#        26279.36533333, 29564.286     , 32849.20666667, 36134.12733333,
#        39419.048     , 42703.96866667, 45988.88933333, 49273.81      ,
#        52558.73066667, 55843.65133333, 59128.572     , 62413.49266667,
#        65698.41333333, 68983.334     , 72268.25466667, 75553.17533333,
#        78838.096     , 82123.01666667, 85407.93733333, 88692.858     ,
#        91977.77866667, 95262.69933333, 98547.62      ])

# %%
def put_value_into_bins(value,bin_edges):
    for i in range(len(bin_edges) - 1):
        if value >= bin_edges[i] and value < bin_edges[i+1]:
            new_val = (bin_edges[i] + bin_edges[i+1] - bin_edges[i])/2
            return new_val

# %%
put_value_into_bins(3000,outputhist[1])
# Out:
# np.float64(1642.4603333333332)

# %%
flood["gfd_area_bin"] = flood["gfd_area"].apply(lambda x: put_value_into_bins(x,outputhist[1]))

# %%
plt.plot(flood['gfd_area_bin']);

# %%
plt.subplot(2,1,1);
plt.plot(flood['gfd_area']);
plt.subplot(2,1,2);
plt.plot(flood['gfd_area_bin']);

# %%
flood['gfd_area_bin'].sort_values()
# Out:
# 907     1642.460333
# 908     1642.460333
# 909     1642.460333
# 912     1642.460333
# 529     1642.460333
#            ...
# 412    39419.048000
# 133    41061.508333
# 547    45988.889333
# 643    49273.810000
# 123             NaN
# Name: gfd_area_bin, Length: 913, dtype: float64

# %%
plt.subplot(2,1,1);
plt.plot(flood['gfd_area'].sort_values().reset_index(drop = True));
plt.subplot(2,1,2);
plt.plot(flood['gfd_area_bin'].sort_values().reset_index(drop = True));

# %% [markdown]
# ### Outlier Removal

# %%
plt.boxplot(flood['gfd_area'],vert=False);

# %%
outputbox = plt.boxplot(flood['gfd_area'],vert=False,whis=10);

# %%
outputbox
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x7d3d6d460dd0>,
#   <matplotlib.lines.Line2D at 0x7d3d6d461340>],
#  'caps': [<matplotlib.lines.Line2D at 0x7d3d6d461760>,
#   <matplotlib.lines.Line2D at 0x7d3d6d461d60>],
#  'boxes': [<matplotlib.lines.Line2D at 0x7d3d6d460350>],
#  'medians': [<matplotlib.lines.Line2D at 0x7d3d6d461a90>],
#  'fliers': [<matplotlib.lines.Line2D at 0x7d3d6d462750>],
#  'means': []}

# %%
outputbox['whiskers'][1].get_xdata()
# Out:
# array([ 7354.55, 68991.93])

# %%
outputbox['whiskers'][0].get_xdata()
# Out:
# array([608.6,   0. ])

# %%
outputbox['fliers'][0].get_xdata()
# Out:
# array([98547.62, 79213.43, 75030.8 , 78785.53, 88773.57, 97982.77])

# %% [markdown]
# remove outlier

# %%
flood_nooutlier = flood[flood['gfd_area']<
                        outputbox['whiskers'][1].get_xdata()[1]]

# %%
outoutbox2 = plt.boxplot(flood_nooutlier['gfd_area'],vert=False,whis=10);

# %% [markdown]
# ตามหาค่า outlier

# %%
flood[flood['gfd_area'] == outputbox['whiskers'][0].get_xdata()[0]]
# Out:
#                            system:index  index threshold_type glide_index  \
# 872  DFO_4485_From_20170612_to_20170614   4485            std         NaN
#
#      dfo_country dfo_other_country  dfo_centroid_x  dfo_centroid_y dfo_began  \
# 872  Philippines               NaN      125.249498         7.76344   6/12/17
#
#     dfo_ended  ... dfo_severity  gfd_area  gfd_exp_ghsl_ts gfd_exp_ghsl_2000  \
# 872   6/14/17  ...          1.0     608.6         359310.0          308601.0
#
#      gfd_exp_ghsl_2015  Errors  dif 2000  dif 2015  error 2000  gfd_area_bin
# 872             359310       1     50709         0         NaN   1642.460333
#
# [1 rows x 24 columns]

# %% [markdown]
# # Data Intergration

# %% [markdown]
# Data exploration

# %%
project_df = pd.read_csv('/content/drive/MyDrive/GreenFN/BSC_DPDM2025/Copy of opendata_project-2.csv')
project_df.head()
# Out:
#    row_number                project_id                     name_en  \
# 0     20809.0  5ec3409884c1860019f3298d    Baan Laksiri Surin-Korco
# 1      4268.0             project_15905              Liberty Park 2
# 2      5849.0  62b2b082cb0d2c0014be01a6  Pleno Paholyothin-Saimai 2
# 3     21762.0              project_6010              Baan Thara Rin
# 4     10751.0             project_11312             The Forest Hill
#
#                       name_th propertytype_id propertytype_name_en  \
# 0  บ้านหลักศิริ สุรินทร์-คอโค               3             Townhome
# 1          ลิเบอร์ตี้ พาร์ค 2               2                Condo
# 2    พลีโน่ พหลโยธิน-สายไหม 2               3             Townhome
# 3              บ้านธารารินทร์               1       Detached House
# 4          เดอะ ฟอเรสต์ ฮิลล์               1       Detached House
#
#   propertytype_name_th  price_min     developer_id  \
# 0             ทาวน์โฮม  1490000.0   developer_7326
# 1                คอนโด  6500000.0  developer_10510
# 2             ทาวน์โฮม  2790000.0   developer_1760
# 3                 บ้าน  3100000.0  developer_10510
# 4                 บ้าน  2450000.0   developer_7313
#
#                 developer_name_en  ... facility_park  facility_playground  \
# 0  LAK SIRI REAL ESTATE CO., LTD.  ...           NaN                  NaN
# 1                             NaN  ...           0.0                  0.0
# 2     AP (THAILAND) PUB CO., LTD.  ...           1.0                  NaN
# 3                             NaN  ...           NaN                  NaN
# 4     Cholsiri Property Co., Ltd.  ...           1.0                  NaN
#
#    facility_pool facility_security         date_created          date_finish  \
# 0            1.0               1.0  2020-05-19 09:12:40                  NaN
# 1            1.0               1.0  2019-06-28 16:06:45  1998-12-31 07:00:00
# 2            1.0               1.0  2022-06-22 13:02:42  2024-01-01 07:00:00
# 3            NaN               NaN  2017-04-19 14:41:10                  NaN
# 4            1.0               1.0  2017-10-30 14:10:50  2018-12-31 07:00:00
#
#           date_updated  source  \
# 0  2020-12-04 10:33:10  baania
# 1  2020-12-04 10:39:27  baania
# 2  2023-03-20 15:00:04  baania
# 3  2022-11-07 12:30:02  baania
# 4  2022-08-15 16:00:05  baania
#
#                                          url_project         day
# 0  https://baania.com/th/project/บ้านหลักศิริ-สุร...  2023-06-11
# 1  https://baania.com/th/project/ลิเบอร์ตี้-พาร์ค...  2023-06-11
# 2  https://baania.com/th/project/พลีโน่-พหลโยธิน-...  2023-06-11
# 3  https://baania.com/th/project/บ้านธารารินทร์-p...  2023-06-11
# 4  https://baania.com/th/project/เดอะ-ฟอเรสต์-ฮิล...  2023-06-11
#
# [5 rows x 46 columns]

# %%
for i in project_df.columns:
    print(i)
# Out:
# row_number
# project_id
# name_en
# name_th
# propertytype_id
# propertytype_name_en
# propertytype_name_th
# price_min
# developer_id
# developer_name_en
# developer_name_th
# latitude
# longitude
# neighborhood_id
# neighborhood_name_en
# neighborhood_name_th
# subdistrict_id
# subdistrict_name_en
# subdistrict_name_th
# district_id
# district_name_en
# district_name_th
# province_id
# province_name_en
# province_name_th
# zipcode
# count_elevator
# count_elevator_service
# count_floor
# count_parking
# count_tower
# count_unit
# count_unittype
# facility_clubhouse
# facility_fitness
# facility_meeting
# facility_park
# facility_playground
# facility_pool
# facility_security
# date_created
# date_finish
# date_updated
# source
# url_project
# day

# %%
unit_df = pd.read_csv('/content/drive/MyDrive/GreenFN/BSC_DPDM2025/Copy of opendata_unittype-2.csv')
unit_df.head()
# Out:
#    row_number               unittype_id                project_id  \
# 0       37586            unittype_35602             project_15270
# 1        9427             unittype_4487              project_1476
# 2       12994            unittype_37624             project_16674
# 3       19073  62286afcc74d880014871357  622861f7aae18f00134066d6
# 4       10907             unittype_8344              project_2821
#
#                name_th  propertytype_id propertytype_name_en  \
# 0               Studio                2                Condo
# 1              ภัทรสิน                3             Townhome
# 2               Type B                3             Townhome
# 3      ทาวน์โฮมสองชั้น                3             Townhome
# 4  2 Bedroom (ขายแล้ว)                2                Condo
#
#   propertytype_name_th  area_total_min_wa  area_usable_min  price_min  ...  \
# 0                คอนโด                NaN             30.0  3700000.0  ...
# 1             ทาวน์โฮม                NaN              NaN  2000000.0  ...
# 2             ทาวน์โฮม               24.0             96.0        NaN  ...
# 3             ทาวน์โฮม                NaN              NaN  1000000.0  ...
# 4                คอนโด                NaN             48.0  4200000.0  ...
#
#    count_room_kitchen  count_room_living  count_room_maid  count_room_storage  \
# 0                 NaN                NaN              NaN                 NaN
# 1                 NaN                NaN              NaN                 NaN
# 2                 NaN                NaN              NaN                 NaN
# 3                 1.0                NaN              NaN                 NaN
# 4                 1.0                1.0              NaN                 NaN
#
#    count_room_utility         date_created         date_updated  source  \
# 0                 NaN  2021-11-12 13:22:56  2020-10-14 20:21:01  baania
# 1                 NaN  2021-11-12 13:20:17  2020-10-14 00:53:00  baania
# 2                 NaN  2022-09-09 15:30:02  2022-09-09 15:03:18  baania
# 3                 NaN  2022-03-09 16:30:04  2022-03-09 16:17:44  baania
# 4                 NaN  2021-11-12 13:24:53  2020-10-16 16:46:17  baania
#
#                                         url_unittype         day
# 0  https://baania.com/th/project/ไลฟ์-แอท-รัชดา-ส...  2023-06-11
# 1  https://baania.com/th/project/บ้านสวนทรัพย์ธาน...  2023-06-11
# 2  https://baania.com/th/project/สกายไลน์-อมตะ-16...  2023-06-11
# 3  https://baania.com/th/project/รุ่งเรืองทรัพย์ว...  2023-06-11
# 4  https://baania.com/th/project/เดอะ-เทมโป-แกรนด...  2023-06-11
#
# [5 rows x 28 columns]

# %%
for i in unit_df.columns:
    print(i)
# Out:
# row_number
# unittype_id
# project_id
# name_th
# propertytype_id
# propertytype_name_en
# propertytype_name_th
# area_total_min_wa
# area_usable_min
# price_min
# count_airconditioner
# count_elevator
# count_floor_internal
# count_parking
# count_room_bath
# count_room_bed
# count_room_dinning
# count_room_guest
# count_room_kitchen
# count_room_living
# count_room_maid
# count_room_storage
# count_room_utility
# date_created
# date_updated
# source
# url_unittype
# day

# %% [markdown]
# ## Add more columns to the table (X-Data intergation)

# %%
unit_df = unit_df.merge(
    project_df[[
        'project_id',
        'name_th',
        'developer_name_th',
        'neighborhood_name_th',
        'subdistrict_name_th',
        'district_name_th',
        'province_name_th'
    ]],
    on='project_id',
    how='left'
)

# %%
print(project_df.columns)
# Out:
# Index(['row_number', 'project_id', 'name_en', 'name_th', 'propertytype_id',
#        'propertytype_name_en', 'propertytype_name_th', 'price_min',
#        'developer_id', 'developer_name_en', 'developer_name_th', 'latitude',
#        'longitude', 'neighborhood_id', 'neighborhood_name_en',
#        'neighborhood_name_th', 'subdistrict_id', 'subdistrict_name_en',
#        'subdistrict_name_th', 'district_id', 'district_name_en',
#        'district_name_th', 'province_id', 'province_name_en',
#        'province_name_th', 'zipcode', 'count_elevator',
#        'count_elevator_service', 'count_floor', 'count_parking', 'count_tower',
#        'count_unit', 'count_unittype', 'facility_clubhouse',
#        'facility_fitness', 'facility_meeting', 'facility_park',
#        'facility_playground', 'facility_pool', 'facility_security',
#        'date_created', 'date_finish', 'date_updated', 'source', 'url_project',
#        'day'],
#       dtype='object')

# %%
project_df_unique_id = project_df.drop_duplicates(subset=['project_id'], keep='last')
unit_df['project_name'] = unit_df['project_id'].map(
    project_df_unique_id.set_index('project_id')['name_th']
)

# %% [markdown]
# ##*Deduplication*

# %% [markdown]
# ดูก่อนว่า Data duplicate ยังไง

# %%
project_df.duplicated().any()
# Out:
# np.True_

# %%
project_df.duplicated().sum()
# Out:
# np.int64(2)

# %%
project_df[project_df.duplicated(keep=False)]
# Out:
#        row_number project_id name_en        name_th propertytype_id  \
# 138           NaN  ขนส่งปทุม    3611      BAN CHANG         บ้านฉาง
# 5610          NaN  ขนส่งปทุม    3611      BAN CHANG         บ้านฉาง
# 8103          NaN  ขนส่งปทุม    3656  BANG PHO NUEA   บางโพธิ์เหนือ
# 10204         NaN  ขนส่งปทุม    3656  BANG PHO NUEA   บางโพธิ์เหนือ
#
#       propertytype_name_en propertytype_name_th      price_min developer_id  \
# 138                   3600  MUEANG PATHUM THANI  เมืองปทุมธานี         3599
# 5610                  3600  MUEANG PATHUM THANI  เมืองปทุมธานี         3599
# 8103                  3647             SAM KHOK         สามโคก         3599
# 10204                 3647             SAM KHOK         สามโคก         3599
#
#       developer_name_en  ... facility_park  facility_playground  \
# 138        Pathum Thani  ...           NaN                  NaN
# 5610       Pathum Thani  ...           NaN                  NaN
# 8103       Pathum Thani  ...           NaN                  NaN
# 10204      Pathum Thani  ...           NaN                  NaN
#
#        facility_pool facility_security date_created date_finish  date_updated  \
# 138              NaN               NaN          NaN         NaN           NaN
# 5610             NaN               NaN          NaN         NaN           NaN
# 8103             NaN               NaN          NaN         NaN           NaN
# 10204            NaN               NaN          NaN         NaN           NaN
#
#       source url_project  day
# 138      NaN         NaN  NaN
# 5610     NaN         NaN  NaN
# 8103     NaN         NaN  NaN
# 10204    NaN         NaN  NaN
#
# [4 rows x 46 columns]

# %%
project_df.duplicated(subset=['project_id'], keep=False).sum()
# Out:
# np.int64(6981)

# %%
project_df[project_df.duplicated(subset=['project_id'], keep=False)].head(20).sort_values(by=['project_id'])
# Out:
#     row_number                project_id                              name_en  \
# 67     15966.0  5e9973839f161600121b5eb3  Nathawadee Grand Park Map Saen Suk
# 78     16607.0  5e9fc23c38be3400128e32d6                 Palmprings Promenade
# 0      20809.0  5ec3409884c1860019f3298d             Baan Laksiri Surin-Korco
# 8       3795.0  5f04029cb285eb00194de1dd                     City park sakaeo
# 55     10827.0  5f2d191e306e7e0019069070             Supalai Ville Sanphisuea
# 34      5047.0  5f34e60ec801fb0019dacbd6                  Taraville Pechabura
# 83     16779.0  600001780b458100134e49cb                  The Ricco Khon Kaen
# 96     14411.0             project_12286                             Au Suite
# 41      2361.0             project_13214                   Phuket Villa Kathu
# 79       411.0             project_14357                              Sansara
# 44       652.0             project_15487                           We Village
# 95     20774.0              project_1712                      Villa De Pastel
# 69      1711.0              project_3087             Baan Pruksa 68 Khon Kaen
# 43     19726.0              project_3669                Roi Pruksa Kampangsan
# 24     12456.0              project_4054          Cubist Townhome Sanambinnam
# 23     20554.0              project_7343                  Baan Nantana Garden
# 38      8813.0              project_7554                    Sanamjan Lakeview
# 91     22589.0              project_8642                     Sirarin Townhome
# 40      8566.0              project_8784    Nara Cluster Romklao-Suvarnabhumi
# 85      9179.0              project_8823                   Vizio Ramkhamhaeng
#
#                                name_th propertytype_id propertytype_name_en  \
# 67       ณฐาวดี แกรนด์ พาร์ค มาบแสนสุข           20000           Twin house
# 78               ปาล์มสปริงส์ พรอมานาด           20000           Twin house
# 0           บ้านหลักศิริ สุรินทร์-คอโค               3             Townhome
# 8                 ซิตี้ปาร์ค สระแก้ว 2               4           Commercial
# 55            ศุภาลัย วิลล์ สันผีเสื้อ               3             Townhome
# 34                    ธาราวิลล์เพชบุระ               3             Townhome
# 83                 เดอะ ริคโค่ ขอนแก่น           20000           Twin house
# 96                             ออลสวีท               3             Townhome
# 41                 ภูเก็ต วิลล่า กะทู้           20000           Twin house
# 79                              แสนสรา               2                Condo
# 44                           วี วิลเลจ               3             Townhome
# 95                   วิลล่า เดอ พาสเทล               1       Detached House
# 69                บ้านพฤกษา 68 ขอนแก่น               1       Detached House
# 43                  ร้อยพฤกษา กำแพงแสน           20000           Twin house
# 24           คิวบิสทาวน์โฮม สนามบินน้ำ               3             Townhome
# 23                บ้านนันทนาการ์เด้นท์               3             Townhome
# 38                   สนามจันทร์ เลควิว               3             Townhome
# 91                    ศิราริน ทาวน์โฮม               3             Townhome
# 40  นารา คลัสเตอร์ ร่มเกล้า-สุวรรณภูมิ               4           Commercial
# 85                     วิซีโอ รามคำแหง               6          Home office
#
#    propertytype_name_th  price_min              developer_id  \
# 67              บ้านแฝด  1690000.0            developer_6192
# 78              บ้านแฝด  3500000.0            developer_8706
# 0              ทาวน์โฮม  1490000.0            developer_7326
# 8          อาคารพาณิชย์  1900000.0  5f03f344b285eb00194de191
# 55             ทาวน์โฮม  2340000.0              developer_97
# 34             ทาวน์โฮม  1000000.0  5f34e256c801fb0019dacbbe
# 83              บ้านแฝด  1990000.0           developer_10510
# 96             ทาวน์โฮม  2500000.0            developer_7929
# 41              บ้านแฝด  2463200.0            developer_8436
# 79                คอนโด  4000000.0            developer_9131
# 44             ทาวน์โฮม  2220000.0            developer_6334
# 95                 บ้าน  2175000.0            developer_1501
# 69                 บ้าน  1350000.0           developer_10510
# 43              บ้านแฝด  1990000.0            developer_2256
# 24             ทาวน์โฮม  3790000.0            developer_2417
# 23             ทาวน์โฮม  1490000.0           developer_10510
# 38             ทาวน์โฮม   750000.0           developer_10510
# 91             ทาวน์โฮม  3690000.0            developer_5755
# 40         อาคารพาณิชย์  3990000.0            developer_5776
# 85            โฮมออฟฟิศ  6100000.0            developer_2041
#
#                                 developer_name_en  ... facility_park  \
# 67                     Trinatawat Company Limited  ...           1.0
# 78                                            NaN  ...           1.0
# 0                  LAK SIRI REAL ESTATE CO., LTD.  ...           NaN
# 8                   Sa Kaeo Development Co., Ltd.  ...           1.0
# 55                 Supalai Public Company Limited  ...           1.0
# 34  Thanthong Property and Construction Co., Ltd.  ...           NaN
# 83                                            NaN  ...           1.0
# 96                                            NaN  ...           NaN
# 41                          Phuket Villa Co.,Ltd.  ...           NaN
# 79                                            NaN  ...           1.0
# 44                                            NaN  ...           NaN
# 95                               Wah Fa Co., Ltd.  ...           NaN
# 69                                            NaN  ...           1.0
# 43                        MIDA PROPERTY CO., LTD.  ...           1.0
# 24                        PLUS PROPERTY CO., LTD.  ...           1.0
# 23                                            NaN  ...           1.0
# 38                                            NaN  ...           NaN
# 91                                            NaN  ...           NaN
# 40                                            NaN  ...           1.0
# 85               HOME PLACE DEVELOPMENT CO., LTD.  ...           1.0
#
#     facility_playground  facility_pool facility_security         date_created  \
# 67                  NaN            NaN               1.0  2020-04-17 16:14:43
# 78                  1.0            NaN               1.0  2020-04-22 11:04:12
# 0                   NaN            1.0               1.0  2020-05-19 09:12:40
# 8                   NaN            NaN               1.0  2020-07-07 12:05:32
# 55                  NaN            NaN               1.0  2020-08-07 16:04:30
# 34                  NaN            NaN               1.0  2020-08-13 14:04:46
# 83                  NaN            NaN               1.0  2021-01-14 15:31:52
# 96                  NaN            1.0               1.0  2017-12-05 16:39:02
# 41                  1.0            1.0               1.0  2018-05-10 14:27:40
# 79                  0.0            1.0               1.0  2018-08-14 10:31:57
# 44                  NaN            NaN               NaN  2019-05-23 14:00:34
# 95                  NaN            NaN               NaN  2016-06-23 10:09:53
# 69                  NaN            1.0               1.0  2016-12-14 08:51:46
# 43                  NaN            1.0               1.0  2017-01-30 11:06:01
# 24                  NaN            NaN               1.0  2017-02-23 13:40:12
# 23                  1.0            1.0               1.0  2017-05-22 11:28:57
# 38                  NaN            NaN               NaN  2017-05-30 15:53:44
# 91                  NaN            NaN               NaN  2017-07-11 15:47:05
# 40                  1.0            NaN               1.0  2017-07-12 14:24:29
# 85                  NaN            NaN               1.0  2017-07-12 16:36:57
#
#             date_finish         date_updated  source  \
# 67  2021-01-01 07:00:00  2021-01-28 11:00:06  baania
# 78  2021-01-01 07:00:00  2020-12-04 10:33:20  baania
# 0                   NaN  2020-12-04 10:33:10  baania
# 8   2016-01-01 07:00:00  2020-12-04 10:33:25  baania
# 55  2021-01-01 07:00:00  2022-01-24 15:30:04  baania
# 34                  NaN  2022-08-04 15:00:08  baania
# 83                  NaN  2022-02-11 18:30:06  baania
# 96                  NaN  2020-12-04 10:42:14  baania
# 41  2013-12-31 07:00:00  2020-12-04 10:44:55  baania
# 79                  NaN  2022-06-06 14:30:04  baania
# 44  2018-01-01 07:00:00  2022-06-21 19:00:06  baania
# 95  2016-04-30 07:00:00  2020-12-04 10:39:10  baania
# 69                  NaN  2020-12-04 10:39:17  baania
# 43                  NaN  2023-05-18 09:30:02  baania
# 24                  NaN  2021-07-15 15:30:11  baania
# 23                  NaN  2020-12-04 10:37:28  baania
# 38                  NaN  2020-12-04 10:37:42  baania
# 91                  NaN  2020-12-04 10:47:14  baania
# 40  2019-01-01 07:00:00  2021-06-30 11:30:04  baania
# 85  2018-01-01 07:00:00  2023-04-06 17:00:08  baania
#
#                                           url_project         day
# 67  https://baania.com/th/project/ณฐาวดี-แกรนด์-พา...  2023-06-11
# 78  https://baania.com/th/project/ปาล์มสปริงส์-พรอ...  2023-06-11
# 0   https://baania.com/th/project/บ้านหลักศิริ-สุร...  2023-06-11
# 8   https://baania.com/th/project/ซิตี้ปาร์ค-สระแก...  2023-06-11
# 55  https://baania.com/th/project/ศุภาลัย-วิลล์-สั...  2023-06-11
# 34  https://baania.com/th/project/ธาราวิลล์เพชบุระ...  2023-06-11
# 83  https://baania.com/th/project/เดอะ-ริคโค่-ขอนแ...  2023-06-11
# 96  https://baania.com/th/project/ออลสวีท-project_...  2023-06-11
# 41  https://baania.com/th/project/ภูเก็ต-วิลล่า-กะ...  2023-06-11
# 79  https://baania.com/th/project/แสนสรา-project_1...  2023-06-11
# 44  https://baania.com/th/project/วี-วิลเลจ-projec...  2023-06-11
# 95  https://baania.com/th/project/วิลล่า-เดอ-พาสเท...  2023-06-11
# 69  https://baania.com/th/project/บ้านพฤกษา-68-ขอน...  2023-06-11
# 43  https://baania.com/th/project/ร้อยพฤกษา-กำแพงแ...  2023-06-11
# 24  https://baania.com/th/project/คิวบิสทาวน์โฮม-ส...  2023-06-11
# 23  https://baania.com/th/project/บ้านนันทนาการ์เด...  2023-06-11
# 38  https://baania.com/th/project/สนามจันทร์-เลควิ...  2023-06-11
# 91  https://baania.com/th/project/ศิราริน-ทาวน์โฮม...  2023-06-11
# 40  https://baania.com/th/project/นารา-คลัสเตอร์-ร...  2023-06-11
# 85  https://baania.com/th/project/วิซีโอ-รามคำแหง-...  2023-06-11
#
# [20 rows x 46 columns]

# %% [markdown]
# ลบข้อมูลที่มี project_id ว้ำกัน โดยเก็บไว้เฉพาะตัวที่เป็นข้อมูลล่าสุด(ตัวอย่าง)

# %%
project_df_drop = project_df.duplicated(subset=['project_id'], keep='last')

# %%
unit_df['ชื่อโครงการ'] = unit_df['project_id'].map(project_df_unique_id.set_index('project_id')['name_th'])

# %%
project_df_drop = project_df.drop_duplicates()

# %% [markdown]
# ## HW3 กลับไปเติมข้อมูล Columns ที่จำเป็นที่เหลือ

# %%
cols = {
    'name_th': 'ชื่อโครงการ',
    'developer_name_th': 'ผู้พัฒนา',
    'neighborhood_name_th': 'ย่าน',
    'subdistrict_name_th': 'ตำบล',
    'district_name_th': 'อำเภอ',
    'province_name_th': 'จังหวัด'
}

unit_df = unit_df.drop(columns=list(cols.values()), errors='ignore')

unit_df = unit_df.join(
    project_df_drop.set_index('project_id')[list(cols.keys())].rename(columns=cols),
    on='project_id'
)

# %% [markdown]
# ## Add more data (Y-Data intergation)

# %% [markdown]
# สมมติว่า Database เก็บแยกชนิดของบ้านและคอนโด

# %%
house = unit_df[unit_df['propertytype_name_th'] == 'บ้าน']
condo = unit_df[unit_df['propertytype_name_th'] == 'คอนโด']

# %% [markdown]
# ฐานข้อมูลบ้าน และ condo

# %%
house.head()
# Out:
#     row_number               unittype_id                project_id  \
# 9        20789  637f2b9413f8b50012598d87  637f2adf13f8b50012598d82
# 13       19169  623add41c74d8800148716b0  623ad6bac74d8800148716ab
# 14       12753            unittype_24670              project_9840
# 14       12753            unittype_24670              project_9840
# 14       12753            unittype_24670              project_9840
#
#             name_th_x  propertytype_id propertytype_name_en  \
# 9              Repose                1       Detached House
# 13  บ้านเดี่ยวสองชั้น                1       Detached House
# 14              วนิดา                1       Detached House
# 14              วนิดา                1       Detached House
# 14              วนิดา                1       Detached House
#
#    propertytype_name_th  area_total_min_wa  area_usable_min  price_min  ...  \
# 9                  บ้าน                NaN              NaN        NaN  ...
# 13                 บ้าน                NaN            100.0  6500000.0  ...
# 14                 บ้าน                NaN            203.0  4600000.0  ...
# 14                 บ้าน                NaN            203.0  4600000.0  ...
# 14                 บ้าน                NaN            203.0  4600000.0  ...
#
#     subdistrict_name_th  district_name_th  province_name_th  \
# 9                ไทรม้า      เมืองนนทบุรี           นนทบุรี
# 13                วิชิต       เมืองภูเก็ต            ภูเก็ต
# 14            สุรศักดิ์           ศรีราชา            ชลบุรี
# 14            สุรศักดิ์           ศรีราชา            ชลบุรี
# 14            สุรศักดิ์           ศรีราชา            ชลบุรี
#
#                          project_name                        ชื่อโครงการ  \
# 9   เพอร์เฟค มาสเตอร์พีซ รัตนาธิเบศร์  เพอร์เฟค มาสเตอร์พีซ รัตนาธิเบศร์
# 13   พนาสนธิ์ การ์เด้นท์ วิลล์ ภูเก็ต   พนาสนธิ์ การ์เด้นท์ วิลล์ ภูเก็ต
# 14                    เพลินวิว ทิวเขา                    เพลินวิว ทิวเขา
# 14                    เพลินวิว ทิวเขา                    เพลินวิว ทิวเขา
# 14                    เพลินวิว ทิวเขา                    เพลินวิว ทิวเขา
#
#                                        ผู้พัฒนา      ย่าน       ตำบล  \
# 9   บริษัท พร็อพเพอร์ตี้ เพอร์เฟค จำกัด (มหาชน)    ท่าอิฐ     ไทรม้า
# 13                  บริษัท พนาสนธิ์ กรุ๊ป จำกัด       NaN      วิชิต
# 14               บริษัท ไลฟ แอนด์ ลีฟวิ่ง จำกัด  เก้ากิโล  สุรศักดิ์
# 14               บริษัท ไลฟ แอนด์ ลีฟวิ่ง จำกัด  เก้ากิโล  สุรศักดิ์
# 14               บริษัท ไลฟ แอนด์ ลีฟวิ่ง จำกัด  เก้ากิโล  สุรศักดิ์
#
#            อำเภอ  จังหวัด
# 9   เมืองนนทบุรี  นนทบุรี
# 13   เมืองภูเก็ต   ภูเก็ต
# 14       ศรีราชา   ชลบุรี
# 14       ศรีราชา   ชลบุรี
# 14       ศรีราชา   ชลบุรี
#
# [5 rows x 41 columns]

# %%
house.shape
# Out:
# (34887, 41)

# %%
condo.head()
# Out:
#     row_number     unittype_id     project_id            name_th_x  \
# 0        37586  unittype_35602  project_15270               Studio
# 7        10907   unittype_8344   project_2821  2 Bedroom (ขายแล้ว)
# 12       33884  unittype_36928  project_15818            1 Bedroom
# 21       34574  unittype_37590  project_16368            4 Bedroom
# 24       39469  unittype_40049  project_17461            2 Bedroom
#
#     propertytype_id propertytype_name_en propertytype_name_th  \
# 0                 2                Condo                คอนโด
# 7                 2                Condo                คอนโด
# 12                2                Condo                คอนโด
# 21                2                Condo                คอนโด
# 24                2                Condo                คอนโด
#
#     area_total_min_wa  area_usable_min   price_min  ...  subdistrict_name_th  \
# 0                 NaN            30.00   3700000.0  ...            สามเสนนอก
# 7                 NaN            48.00   4200000.0  ...               บางค้อ
# 12                NaN            49.00   3350000.0  ...         คลองตันเหนือ
# 21                NaN           170.00  15900000.0  ...                 สีลม
# 24                NaN            48.88   4700000.0  ...                จอมพล
#
#     district_name_th  province_name_th                    project_name  \
# 0           ห้วยขวาง     กรุงเทพมหานคร       ไลฟ์ แอท รัชดา - สุทธิสาร
# 7             จอมทอง     กรุงเทพมหานคร  เดอะ เทมโป แกรนด์ สาทร-วุฒากาศ
# 12             วัฒนา     กรุงเทพมหานคร                ทองหล่อ ทาวเวอร์
# 21            บางรัก     กรุงเทพมหานคร        จิวเวลรี่ เทรด เซ็นเตอร์
# 24           จตุจักร     กรุงเทพมหานคร                 อะไรส์ รัชดา 19
#
#                        ชื่อโครงการ                                   ผู้พัฒนา  \
# 0        ไลฟ์ แอท รัชดา - สุทธิสาร       บริษัท เอพี (ไทยแลนด์) จำกัด (มหาชน)
# 7   เดอะ เทมโป แกรนด์ สาทร-วุฒากาศ           บริษัท บิลท์ แลนด์ จำกัด (มหาชน)
# 12                ทองหล่อ ทาวเวอร์                                        NaN
# 21        จิวเวลรี่ เทรด เซ็นเตอร์  บริษัท ซินเท็ค คอนสตรัคชั่น จำกัด (มหาชน)
# 24                 อะไรส์ รัชดา 19    บริษัท ฟอร์จูน พลัส พร็อพเพอร์ตี้ จำกัด
#
#              ย่าน          ตำบล     อำเภอ        จังหวัด
# 0        สุทธิสาร     สามเสนนอก  ห้วยขวาง  กรุงเทพมหานคร
# 7         วุฒากาศ        บางค้อ    จอมทอง  กรุงเทพมหานคร
# 12        ทองหล่อ  คลองตันเหนือ     วัฒนา  กรุงเทพมหานคร
# 21           สีลม          สีลม    บางรัก  กรุงเทพมหานคร
# 24  สถานีลาดพร้าว         จอมพล   จตุจักร  กรุงเทพมหานคร
#
# [5 rows x 41 columns]

# %%
condo.shape
# Out:
# (13157, 41)

# %% [markdown]
# ## Data Transformation

# %% [markdown]
# ในกรณีที่ต่าง column ต่างหน่วย ต้องแปลงข้อมูลก่อน

# %%
project_df_drop
# Out:
#        row_number                project_id                     name_en  \
# 0         20809.0  5ec3409884c1860019f3298d    Baan Laksiri Surin-Korco
# 1          4268.0             project_15905              Liberty Park 2
# 2          5849.0  62b2b082cb0d2c0014be01a6  Pleno Paholyothin-Saimai 2
# 3         21762.0              project_6010              Baan Thara Rin
# 4         10751.0             project_11312             The Forest Hill
# ...           ...                       ...                         ...
# 23862     17534.0              project_9330   Parinyada Wongwan Sathorn
# 23863     12360.0              project_9316              Sinwong Garden
# 23864      6865.0             project_15993      La Maison Sukhumvit 22
# 23865        74.0               project_105                    Regent 1
# 23866     20538.0  5f2bcbd0306e7e0019068db0     Baanruenrom Nongphueng
#
#                           name_th propertytype_id propertytype_name_en  \
# 0      บ้านหลักศิริ สุรินทร์-คอโค               3             Townhome
# 1              ลิเบอร์ตี้ พาร์ค 2               2                Condo
# 2        พลีโน่ พหลโยธิน-สายไหม 2               3             Townhome
# 3                  บ้านธารารินทร์               1       Detached House
# 4              เดอะ ฟอเรสต์ ฮิลล์               1       Detached House
# ...                           ...             ...                  ...
# 23862          ปริญญดา วงแหวนสาทร               1       Detached House
# 23863             สินวงศ์การ์เด้น           20000           Twin house
# 23864         ลาเมซอง สุขุมวิท 22               2                Condo
# 23865                  รีเจ้นท์ 1               1       Detached House
# 23866       บ้านรื่นรมย์ หนองผึ้ง               1       Detached House
#
#       propertytype_name_th  price_min     developer_id  \
# 0                 ทาวน์โฮม  1490000.0   developer_7326
# 1                    คอนโด  6500000.0  developer_10510
# 2                 ทาวน์โฮม  2790000.0   developer_1760
# 3                     บ้าน  3100000.0  developer_10510
# 4                     บ้าน  2450000.0   developer_7313
# ...                    ...        ...              ...
# 23862                 บ้าน  4780000.0   developer_1762
# 23863              บ้านแฝด  1280000.0  developer_10510
# 23864                คอนโด  9350000.0  developer_10510
# 23865                 บ้าน  3100000.0    developer_100
# 23866                 บ้าน  2500000.0  developer_10510
#
#                     developer_name_en  ... facility_park  facility_playground  \
# 0      LAK SIRI REAL ESTATE CO., LTD.  ...           NaN                  NaN
# 1                                 NaN  ...           0.0                  0.0
# 2         AP (THAILAND) PUB CO., LTD.  ...           1.0                  NaN
# 3                                 NaN  ...           NaN                  NaN
# 4         Cholsiri Property Co., Ltd.  ...           1.0                  NaN
# ...                               ...  ...           ...                  ...
# 23862                             NaN  ...           1.0                  NaN
# 23863                             NaN  ...           NaN                  NaN
# 23864                             NaN  ...           NaN                  NaN
# 23865     THE TROPICAL HOME CO., LTD.  ...           NaN                  NaN
# 23866                             NaN  ...           NaN                  NaN
#
#        facility_pool facility_security         date_created  \
# 0                1.0               1.0  2020-05-19 09:12:40
# 1                1.0               1.0  2019-06-28 16:06:45
# 2                1.0               1.0  2022-06-22 13:02:42
# 3                NaN               NaN  2017-04-19 14:41:10
# 4                1.0               1.0  2017-10-30 14:10:50
# ...              ...               ...                  ...
# 23862            1.0               1.0  2017-08-22 16:58:38
# 23863            NaN               1.0  2017-08-22 15:19:06
# 23864            1.0               1.0  2019-07-02 15:34:11
# 23865            1.0               1.0  2015-09-23 09:06:27
# 23866            NaN               NaN  2020-08-06 16:22:24
#
#                date_finish         date_updated  source  \
# 0                      NaN  2020-12-04 10:33:10  baania
# 1      1998-12-31 07:00:00  2020-12-04 10:39:27  baania
# 2      2024-01-01 07:00:00  2023-03-20 15:00:04  baania
# 3                      NaN  2022-11-07 12:30:02  baania
# 4      2018-12-31 07:00:00  2022-08-15 16:00:05  baania
# ...                    ...                  ...     ...
# 23862  2006-12-31 07:00:00  2020-12-04 10:46:24  baania
# 23863                  NaN  2023-02-02 18:30:02  baania
# 23864  1994-12-31 07:00:00  2021-07-05 12:00:14  baania
# 23865                  NaN  2020-12-04 10:44:04  baania
# 23866  2020-01-01 07:00:00  2020-12-04 10:49:31  baania
#
#                                              url_project         day
# 0      https://baania.com/th/project/บ้านหลักศิริ-สุร...  2023-06-11
# 1      https://baania.com/th/project/ลิเบอร์ตี้-พาร์ค...  2023-06-11
# 2      https://baania.com/th/project/พลีโน่-พหลโยธิน-...  2023-06-11
# 3      https://baania.com/th/project/บ้านธารารินทร์-p...  2023-06-11
# 4      https://baania.com/th/project/เดอะ-ฟอเรสต์-ฮิล...  2023-06-11
# ...                                                  ...         ...
# 23862  https://baania.com/th/project/ปริญญดา-วงแหวนสา...  2023-06-11
# 23863  https://baania.com/th/project/สินวงศ์การ์เด้น-...  2023-06-11
# 23864  https://baania.com/th/project/ลาเมซอง-สุขุมวิท...  2023-06-11
# 23865  https://baania.com/th/project/รีเจ้นท์-1-proje...  2023-06-11
# 23866  https://baania.com/th/project/บ้านรื่นรมย์-หนอ...  2023-06-11
#
# [23865 rows x 46 columns]

# %%
house['price_min'] = house['price_min']/1000000
house
# Out:
#        row_number               unittype_id                project_id  \
# 9           20789  637f2b9413f8b50012598d87  637f2adf13f8b50012598d82
# 13          19169  623add41c74d8800148716b0  623ad6bac74d8800148716ab
# 14          12753            unittype_24670              project_9840
# 14          12753            unittype_24670              project_9840
# 14          12753            unittype_24670              project_9840
# ...           ...                       ...                       ...
# 55609        2451            unittype_13544              project_5287
# 55612        1055             unittype_5786              project_1886
# 55616       20108  630dc1c8713e23001a6a6bb1  630dc0f7713e23001a6a6ba9
# 55619        9507             unittype_5086              project_1635
# 55620       23721            unittype_15644              project_6109
#
#                       name_th_x  propertytype_id propertytype_name_en  \
# 9                        Repose                1       Detached House
# 13            บ้านเดี่ยวสองชั้น                1       Detached House
# 14                        วนิดา                1       Detached House
# 14                        วนิดา                1       Detached House
# 14                        วนิดา                1       Detached House
# ...                         ...              ...                  ...
# 55609  บ้านเดี่ยวสองชั้น Type B                1       Detached House
# 55612           กฤษณา PLUS-EV89                1       Detached House
# 55616                    Type A                1       Detached House
# 55619       บ้านเดี่ยวชั้นเดียว                1       Detached House
# 55620         บ้านเดี่ยวสองชั้น                1       Detached House
#
#       propertytype_name_th  area_total_min_wa  area_usable_min  price_min  \
# 9                     บ้าน                NaN              NaN        NaN
# 13                    บ้าน                NaN            100.0     6.5000
# 14                    บ้าน                NaN            203.0     4.6000
# 14                    บ้าน                NaN            203.0     4.6000
# 14                    บ้าน                NaN            203.0     4.6000
# ...                    ...                ...              ...        ...
# 55609                 บ้าน                NaN            160.0     3.2000
# 55612                 บ้าน                2.0            170.0     3.8614
# 55616                 บ้าน                NaN            186.0     5.3900
# 55619                 บ้าน                NaN              NaN     0.8800
# 55620                 บ้าน               45.0            140.0     2.4000
#
#        ...  subdistrict_name_th  district_name_th  province_name_th  \
# 9      ...               ไทรม้า      เมืองนนทบุรี           นนทบุรี
# 13     ...                วิชิต       เมืองภูเก็ต            ภูเก็ต
# 14     ...            สุรศักดิ์           ศรีราชา            ชลบุรี
# 14     ...            สุรศักดิ์           ศรีราชา            ชลบุรี
# 14     ...            สุรศักดิ์           ศรีราชา            ชลบุรี
# ...    ...                  ...               ...               ...
# 55609  ...              บางใหญ่           บางใหญ่           นนทบุรี
# 55612  ...               พระลับ      เมืองขอนแก่น           ขอนแก่น
# 55616  ...              ไทรน้อย           ไทรน้อย           นนทบุรี
# 55619  ...             บ้านใหม่   เมืองนครราชสีมา        นครราชสีมา
# 55620  ...         คู้ฝั่งเหนือ           หนองจอก     กรุงเทพมหานคร
#
#                             project_name                        ชื่อโครงการ  \
# 9      เพอร์เฟค มาสเตอร์พีซ รัตนาธิเบศร์  เพอร์เฟค มาสเตอร์พีซ รัตนาธิเบศร์
# 13      พนาสนธิ์ การ์เด้นท์ วิลล์ ภูเก็ต   พนาสนธิ์ การ์เด้นท์ วิลล์ ภูเก็ต
# 14                       เพลินวิว ทิวเขา                    เพลินวิว ทิวเขา
# 14                       เพลินวิว ทิวเขา                    เพลินวิว ทิวเขา
# 14                       เพลินวิว ทิวเขา                    เพลินวิว ทิวเขา
# ...                                  ...                                ...
# 55609                 บ้านณัฐชากรีนวิลล์                 บ้านณัฐชากรีนวิลล์
# 55612           กลันตา พลัส อีโค่ วิลเลจ           กลันตา พลัส อีโค่ วิลเลจ
# 55616                           ชวนชม 5                            ชวนชม 5
# 55619             บ้านคุรุสภา นครราชสีมา             บ้านคุรุสภา นครราชสีมา
# 55620                     บ้านเต็มสิริ 1                     บ้านเต็มสิริ 1
#
#                                           ผู้พัฒนา        ย่าน          ตำบล  \
# 9      บริษัท พร็อพเพอร์ตี้ เพอร์เฟค จำกัด (มหาชน)      ท่าอิฐ        ไทรม้า
# 13                     บริษัท พนาสนธิ์ กรุ๊ป จำกัด         NaN         วิชิต
# 14                  บริษัท ไลฟ แอนด์ ลีฟวิ่ง จำกัด    เก้ากิโล     สุรศักดิ์
# 14                  บริษัท ไลฟ แอนด์ ลีฟวิ่ง จำกัด    เก้ากิโล     สุรศักดิ์
# 14                  บริษัท ไลฟ แอนด์ ลีฟวิ่ง จำกัด    เก้ากิโล     สุรศักดิ์
# ...                                            ...         ...           ...
# 55609                                          NaN     ปลายบาง       บางใหญ่
# 55612                บริษัท อีสาน พิมานกรุ๊ป จำกัด  บึงแก่นนคร        พระลับ
# 55616             บริษัท เวลธ์ ดีเวลลอปเปอร์ จำกัด     ไทรน้อย       ไทรน้อย
# 55619                                          NaN   บ้านใหม่1      บ้านใหม่
# 55620                                          NaN     หนองจอก  คู้ฝั่งเหนือ
#
#                  อำเภอ        จังหวัด
# 9         เมืองนนทบุรี        นนทบุรี
# 13         เมืองภูเก็ต         ภูเก็ต
# 14             ศรีราชา         ชลบุรี
# 14             ศรีราชา         ชลบุรี
# 14             ศรีราชา         ชลบุรี
# ...                ...            ...
# 55609          บางใหญ่        นนทบุรี
# 55612     เมืองขอนแก่น        ขอนแก่น
# 55616          ไทรน้อย        นนทบุรี
# 55619  เมืองนครราชสีมา     นครราชสีมา
# 55620          หนองจอก  กรุงเทพมหานคร
#
# [34887 rows x 41 columns]

# %% [markdown]
# ตรวจสอบ scale คราวๆ

# %%
from matplotlib import pyplot as plt

# %%
plt.scatter(range(len(condo['price_min'])),condo['price_min'],c='r')
plt.scatter(range(len(house['price_min'])),house['price_min'],c='r')

# %% [markdown]
# แปลงค่าหน่วยคอนโดหลักล้านแล้วรวม data

# %%
condo['price_min'] = condo['price_min']/1000000
condo_house = pd.concat([house,condo])
plt.scatter(range(len(condo['price_min'])),condo['price_min'],c='r');

# %%
condo_house[condo_house['price_min'] > 300]
# Out:
#        row_number               unittype_id                project_id  \
# 39131       21591  63f6e58e9b028e00130ae6f6  63f6e3b09b028e00130ae6e5
#
#                name_th_x  propertytype_id propertytype_name_en  \
# 39131  บ้านเดี่ยวสามชั้น                1       Detached House
#
#       propertytype_name_th  area_total_min_wa  area_usable_min  price_min  \
# 39131                 บ้าน                NaN           2918.0      385.0
#
#        ...  subdistrict_name_th  district_name_th  province_name_th  \
# 39131  ...             หนองปรือ          บางละมุง            ชลบุรี
#
#        project_name  ชื่อโครงการ                             ผู้พัฒนา  \
# 39131        อสงไขย       อสงไขย  บริษัท อาเมทัส ดีเวลลอปเม้นท์ จำกัด
#
#                ย่าน      ตำบล     อำเภอ  จังหวัด
# 39131  เขาพระตำหนัก  หนองปรือ  บางละมุง   ชลบุรี
#
# [1 rows x 41 columns]

# %% [markdown]
# ## Column Alignment

# %% [markdown]
# สลับ column ของ data condo

# %%
columns_title = ['row_number', 'unittype_id', 'project_id', 'name_th_x',
       'propertytype_id', 'propertytype_name_en', 'propertytype_name_th',
       'area_total_min_wa', 'area_usable_min', 'price_min',
       'count_airconditioner', 'count_elevator', 'count_floor_internal',
       'count_parking', 'count_room_bath', 'count_room_bed',
       'count_room_dinning', 'count_room_guest', 'count_room_kitchen',
       'count_room_living', 'count_room_maid', 'count_room_storage',
       'count_room_utility', 'date_created', 'date_updated', 'source',
       'url_unittype', 'day', 'name_th_y', 'developer_name_th',
       'neighborhood_name_th', 'subdistrict_name_th', 'district_name_th',
       'province_name_th', 'project_name', 'ชื่อโครงการ', 'ผู้พัฒนา', 'ย่าน',
       'ตำบล', 'อำเภอ', 'จังหวัด']

# %%
condo_swap = condo.reindex(columns=columns_title)

# %%
condo_swap.head()
# Out:
#     row_number     unittype_id     project_id            name_th_x  \
# 0        37586  unittype_35602  project_15270               Studio
# 7        10907   unittype_8344   project_2821  2 Bedroom (ขายแล้ว)
# 12       33884  unittype_36928  project_15818            1 Bedroom
# 21       34574  unittype_37590  project_16368            4 Bedroom
# 24       39469  unittype_40049  project_17461            2 Bedroom
#
#     propertytype_id propertytype_name_en propertytype_name_th  \
# 0                 2                Condo                คอนโด
# 7                 2                Condo                คอนโด
# 12                2                Condo                คอนโด
# 21                2                Condo                คอนโด
# 24                2                Condo                คอนโด
#
#     area_total_min_wa  area_usable_min     price_min  ...  \
# 0                 NaN            30.00  3.700000e-18  ...
# 7                 NaN            48.00  4.200000e-18  ...
# 12                NaN            49.00  3.350000e-18  ...
# 21                NaN           170.00  1.590000e-17  ...
# 24                NaN            48.88  4.700000e-18  ...
#
#     subdistrict_name_th  district_name_th  province_name_th  \
# 0             สามเสนนอก          ห้วยขวาง     กรุงเทพมหานคร
# 7                บางค้อ            จอมทอง     กรุงเทพมหานคร
# 12         คลองตันเหนือ             วัฒนา     กรุงเทพมหานคร
# 21                 สีลม            บางรัก     กรุงเทพมหานคร
# 24                จอมพล           จตุจักร     กรุงเทพมหานคร
#
#                       project_name                     ชื่อโครงการ  \
# 0        ไลฟ์ แอท รัชดา - สุทธิสาร       ไลฟ์ แอท รัชดา - สุทธิสาร
# 7   เดอะ เทมโป แกรนด์ สาทร-วุฒากาศ  เดอะ เทมโป แกรนด์ สาทร-วุฒากาศ
# 12                ทองหล่อ ทาวเวอร์                ทองหล่อ ทาวเวอร์
# 21        จิวเวลรี่ เทรด เซ็นเตอร์        จิวเวลรี่ เทรด เซ็นเตอร์
# 24                 อะไรส์ รัชดา 19                 อะไรส์ รัชดา 19
#
#                                      ผู้พัฒนา           ย่าน          ตำบล  \
# 0        บริษัท เอพี (ไทยแลนด์) จำกัด (มหาชน)       สุทธิสาร     สามเสนนอก
# 7            บริษัท บิลท์ แลนด์ จำกัด (มหาชน)        วุฒากาศ        บางค้อ
# 12                                        NaN        ทองหล่อ  คลองตันเหนือ
# 21  บริษัท ซินเท็ค คอนสตรัคชั่น จำกัด (มหาชน)           สีลม          สีลม
# 24    บริษัท ฟอร์จูน พลัส พร็อพเพอร์ตี้ จำกัด  สถานีลาดพร้าว         จอมพล
#
#        อำเภอ        จังหวัด
# 0   ห้วยขวาง  กรุงเทพมหานคร
# 7     จอมทอง  กรุงเทพมหานคร
# 12     วัฒนา  กรุงเทพมหานคร
# 21    บางรัก  กรุงเทพมหานคร
# 24   จตุจักร  กรุงเทพมหานคร
#
# [5 rows x 41 columns]

# %%
condo.columns
# Out:
# Index(['row_number', 'unittype_id', 'project_id', 'name_th_x',
#        'propertytype_id', 'propertytype_name_en', 'propertytype_name_th',
#        'area_total_min_wa', 'area_usable_min', 'price_min',
#        'count_airconditioner', 'count_elevator', 'count_floor_internal',
#        'count_parking', 'count_room_bath', 'count_room_bed',
#        'count_room_dinning', 'count_room_guest', 'count_room_kitchen',
#        'count_room_living', 'count_room_maid', 'count_room_storage',
#        'count_room_utility', 'date_created', 'date_updated', 'source',
#        'url_unittype', 'day', 'name_th_y', 'developer_name_th',
#        'neighborhood_name_th', 'subdistrict_name_th', 'district_name_th',
#        'province_name_th', 'project_name', 'ชื่อโครงการ', 'ผู้พัฒนา', 'ย่าน',
#        'ตำบล', 'อำเภอ', 'จังหวัด'],
#       dtype='object')

# %%
condoswap_house = pd.concat([condo_swap,house])

# %%
condoswap_house.head()
# Out:
#     row_number     unittype_id     project_id            name_th_x  \
# 0        37586  unittype_35602  project_15270               Studio
# 7        10907   unittype_8344   project_2821  2 Bedroom (ขายแล้ว)
# 12       33884  unittype_36928  project_15818            1 Bedroom
# 21       34574  unittype_37590  project_16368            4 Bedroom
# 24       39469  unittype_40049  project_17461            2 Bedroom
#
#     propertytype_id propertytype_name_en propertytype_name_th  \
# 0                 2                Condo                คอนโด
# 7                 2                Condo                คอนโด
# 12                2                Condo                คอนโด
# 21                2                Condo                คอนโด
# 24                2                Condo                คอนโด
#
#     area_total_min_wa  area_usable_min     price_min  ...  \
# 0                 NaN            30.00  3.700000e-18  ...
# 7                 NaN            48.00  4.200000e-18  ...
# 12                NaN            49.00  3.350000e-18  ...
# 21                NaN           170.00  1.590000e-17  ...
# 24                NaN            48.88  4.700000e-18  ...
#
#     subdistrict_name_th  district_name_th  province_name_th  \
# 0             สามเสนนอก          ห้วยขวาง     กรุงเทพมหานคร
# 7                บางค้อ            จอมทอง     กรุงเทพมหานคร
# 12         คลองตันเหนือ             วัฒนา     กรุงเทพมหานคร
# 21                 สีลม            บางรัก     กรุงเทพมหานคร
# 24                จอมพล           จตุจักร     กรุงเทพมหานคร
#
#                       project_name                     ชื่อโครงการ  \
# 0        ไลฟ์ แอท รัชดา - สุทธิสาร       ไลฟ์ แอท รัชดา - สุทธิสาร
# 7   เดอะ เทมโป แกรนด์ สาทร-วุฒากาศ  เดอะ เทมโป แกรนด์ สาทร-วุฒากาศ
# 12                ทองหล่อ ทาวเวอร์                ทองหล่อ ทาวเวอร์
# 21        จิวเวลรี่ เทรด เซ็นเตอร์        จิวเวลรี่ เทรด เซ็นเตอร์
# 24                 อะไรส์ รัชดา 19                 อะไรส์ รัชดา 19
#
#                                      ผู้พัฒนา           ย่าน          ตำบล  \
# 0        บริษัท เอพี (ไทยแลนด์) จำกัด (มหาชน)       สุทธิสาร     สามเสนนอก
# 7            บริษัท บิลท์ แลนด์ จำกัด (มหาชน)        วุฒากาศ        บางค้อ
# 12                                        NaN        ทองหล่อ  คลองตันเหนือ
# 21  บริษัท ซินเท็ค คอนสตรัคชั่น จำกัด (มหาชน)           สีลม          สีลม
# 24    บริษัท ฟอร์จูน พลัส พร็อพเพอร์ตี้ จำกัด  สถานีลาดพร้าว         จอมพล
#
#        อำเภอ        จังหวัด
# 0   ห้วยขวาง  กรุงเทพมหานคร
# 7     จอมทอง  กรุงเทพมหานคร
# 12     วัฒนา  กรุงเทพมหานคร
# 21    บางรัก  กรุงเทพมหานคร
# 24   จตุจักร  กรุงเทพมหานคร
#
# [5 rows x 41 columns]

# %%
condoswap_house.tail()
# Out:
#        row_number               unittype_id                project_id  \
# 55609        2451            unittype_13544              project_5287
# 55612        1055             unittype_5786              project_1886
# 55616       20108  630dc1c8713e23001a6a6bb1  630dc0f7713e23001a6a6ba9
# 55619        9507             unittype_5086              project_1635
# 55620       23721            unittype_15644              project_6109
#
#                       name_th_x  propertytype_id propertytype_name_en  \
# 55609  บ้านเดี่ยวสองชั้น Type B                1       Detached House
# 55612           กฤษณา PLUS-EV89                1       Detached House
# 55616                    Type A                1       Detached House
# 55619       บ้านเดี่ยวชั้นเดียว                1       Detached House
# 55620         บ้านเดี่ยวสองชั้น                1       Detached House
#
#       propertytype_name_th  area_total_min_wa  area_usable_min  price_min  \
# 55609                 บ้าน                NaN            160.0     3.2000
# 55612                 บ้าน                2.0            170.0     3.8614
# 55616                 บ้าน                NaN            186.0     5.3900
# 55619                 บ้าน                NaN              NaN     0.8800
# 55620                 บ้าน               45.0            140.0     2.4000
#
#        ...  subdistrict_name_th  district_name_th  province_name_th  \
# 55609  ...              บางใหญ่           บางใหญ่           นนทบุรี
# 55612  ...               พระลับ      เมืองขอนแก่น           ขอนแก่น
# 55616  ...              ไทรน้อย           ไทรน้อย           นนทบุรี
# 55619  ...             บ้านใหม่   เมืองนครราชสีมา        นครราชสีมา
# 55620  ...         คู้ฝั่งเหนือ           หนองจอก     กรุงเทพมหานคร
#
#                    project_name               ชื่อโครงการ  \
# 55609        บ้านณัฐชากรีนวิลล์        บ้านณัฐชากรีนวิลล์
# 55612  กลันตา พลัส อีโค่ วิลเลจ  กลันตา พลัส อีโค่ วิลเลจ
# 55616                  ชวนชม 5                   ชวนชม 5
# 55619    บ้านคุรุสภา นครราชสีมา    บ้านคุรุสภา นครราชสีมา
# 55620            บ้านเต็มสิริ 1            บ้านเต็มสิริ 1
#
#                                ผู้พัฒนา        ย่าน          ตำบล  \
# 55609                               NaN     ปลายบาง       บางใหญ่
# 55612     บริษัท อีสาน พิมานกรุ๊ป จำกัด  บึงแก่นนคร        พระลับ
# 55616  บริษัท เวลธ์ ดีเวลลอปเปอร์ จำกัด     ไทรน้อย       ไทรน้อย
# 55619                               NaN   บ้านใหม่1      บ้านใหม่
# 55620                               NaN     หนองจอก  คู้ฝั่งเหนือ
#
#                  อำเภอ        จังหวัด
# 55609          บางใหญ่        นนทบุรี
# 55612     เมืองขอนแก่น        ขอนแก่น
# 55616          ไทรน้อย        นนทบุรี
# 55619  เมืองนครราชสีมา     นครราชสีมา
# 55620          หนองจอก  กรุงเทพมหานคร
#
# [5 rows x 41 columns]

# %% [markdown]
# ## Add Data Source Column

# %%
house=house.drop(columns=['propertytype_id','propertytype_name_en','propertytype_name_th'])
condo=condo.drop(columns=['propertytype_id','propertytype_name_en','propertytype_name_th'])

# %%
condo.head()
# Out:
#     row_number     unittype_id     project_id            name_th_x  \
# 0        37586  unittype_35602  project_15270               Studio
# 7        10907   unittype_8344   project_2821  2 Bedroom (ขายแล้ว)
# 12       33884  unittype_36928  project_15818            1 Bedroom
# 21       34574  unittype_37590  project_16368            4 Bedroom
# 24       39469  unittype_40049  project_17461            2 Bedroom
#
#     area_total_min_wa  area_usable_min     price_min  count_airconditioner  \
# 0                 NaN            30.00  3.700000e-18                   NaN
# 7                 NaN            48.00  4.200000e-18                   NaN
# 12                NaN            49.00  3.350000e-18                   NaN
# 21                NaN           170.00  1.590000e-17                   NaN
# 24                NaN            48.88  4.700000e-18                   NaN
#
#     count_elevator  count_floor_internal  ...  subdistrict_name_th  \
# 0              NaN                   NaN  ...            สามเสนนอก
# 7              NaN                   NaN  ...               บางค้อ
# 12             NaN                   NaN  ...         คลองตันเหนือ
# 21             NaN                   NaN  ...                 สีลม
# 24             NaN                   NaN  ...                จอมพล
#
#     district_name_th  province_name_th                    project_name  \
# 0           ห้วยขวาง     กรุงเทพมหานคร       ไลฟ์ แอท รัชดา - สุทธิสาร
# 7             จอมทอง     กรุงเทพมหานคร  เดอะ เทมโป แกรนด์ สาทร-วุฒากาศ
# 12             วัฒนา     กรุงเทพมหานคร                ทองหล่อ ทาวเวอร์
# 21            บางรัก     กรุงเทพมหานคร        จิวเวลรี่ เทรด เซ็นเตอร์
# 24           จตุจักร     กรุงเทพมหานคร                 อะไรส์ รัชดา 19
#
#                        ชื่อโครงการ                                   ผู้พัฒนา  \
# 0        ไลฟ์ แอท รัชดา - สุทธิสาร       บริษัท เอพี (ไทยแลนด์) จำกัด (มหาชน)
# 7   เดอะ เทมโป แกรนด์ สาทร-วุฒากาศ           บริษัท บิลท์ แลนด์ จำกัด (มหาชน)
# 12                ทองหล่อ ทาวเวอร์                                        NaN
# 21        จิวเวลรี่ เทรด เซ็นเตอร์  บริษัท ซินเท็ค คอนสตรัคชั่น จำกัด (มหาชน)
# 24                 อะไรส์ รัชดา 19    บริษัท ฟอร์จูน พลัส พร็อพเพอร์ตี้ จำกัด
#
#              ย่าน          ตำบล     อำเภอ        จังหวัด
# 0        สุทธิสาร     สามเสนนอก  ห้วยขวาง  กรุงเทพมหานคร
# 7         วุฒากาศ        บางค้อ    จอมทอง  กรุงเทพมหานคร
# 12        ทองหล่อ  คลองตันเหนือ     วัฒนา  กรุงเทพมหานคร
# 21           สีลม          สีลม    บางรัก  กรุงเทพมหานคร
# 24  สถานีลาดพร้าว         จอมพล   จตุจักร  กรุงเทพมหานคร
#
# [5 rows x 38 columns]

# %%
house['data_source'] = 'house'
condo['data_source'] = 'condo'
condo_house_data_source = pd.concat([house,condo])

# %%
condo_house_data_source
# Out:
#        row_number               unittype_id                project_id  \
# 9           20789  637f2b9413f8b50012598d87  637f2adf13f8b50012598d82
# 13          19169  623add41c74d8800148716b0  623ad6bac74d8800148716ab
# 14          12753            unittype_24670              project_9840
# 14          12753            unittype_24670              project_9840
# 14          12753            unittype_24670              project_9840
# ...           ...                       ...                       ...
# 55598       17263  60488b2e582962001402e663  60488aeca8b9ee0013d7ebac
# 55602       32766            unittype_32126             project_13619
# 55613       12599            unittype_24778              project_9877
# 55615       11147            unittype_35831             project_15356
# 55623        9465            unittype_35686             project_15298
#
#                name_th_x  area_total_min_wa  area_usable_min     price_min  \
# 9                 Repose                NaN              NaN           NaN
# 13     บ้านเดี่ยวสองชั้น                NaN            100.0  6.500000e+00
# 14                 วนิดา                NaN            203.0  4.600000e+00
# 14                 วนิดา                NaN            203.0  4.600000e+00
# 14                 วนิดา                NaN            203.0  4.600000e+00
# ...                  ...                ...              ...           ...
# 55598          1 Bedroom                NaN              NaN           NaN
# 55602         1 Bedroom                 NaN             31.0  6.500000e-18
# 55613          2 Bedroom                NaN             49.0  3.500000e-18
# 55615             Studio                NaN             27.0  4.990000e-18
# 55623          2 Bedroom                NaN             45.0  3.490000e-18
#
#        count_airconditioner  count_elevator  count_floor_internal  ...  \
# 9                       NaN             NaN                   2.0  ...
# 13                      NaN             NaN                   2.0  ...
# 14                      NaN             NaN                   2.0  ...
# 14                      NaN             NaN                   2.0  ...
# 14                      NaN             NaN                   2.0  ...
# ...                     ...             ...                   ...  ...
# 55598                   NaN             NaN                   NaN  ...
# 55602                   NaN             NaN                   NaN  ...
# 55613                   NaN             NaN                   NaN  ...
# 55615                   NaN             NaN                   NaN  ...
# 55623                   NaN             NaN                   NaN  ...
#
#        district_name_th  province_name_th                       project_name  \
# 9          เมืองนนทบุรี           นนทบุรี  เพอร์เฟค มาสเตอร์พีซ รัตนาธิเบศร์
# 13          เมืองภูเก็ต            ภูเก็ต   พนาสนธิ์ การ์เด้นท์ วิลล์ ภูเก็ต
# 14              ศรีราชา            ชลบุรี                    เพลินวิว ทิวเขา
# 14              ศรีราชา            ชลบุรี                    เพลินวิว ทิวเขา
# 14              ศรีราชา            ชลบุรี                    เพลินวิว ทิวเขา
# ...                 ...               ...                                ...
# 55598            บางเขน     กรุงเทพมหานคร      เดอะ ไพรเวซี่ พาร์ค รามอินทรา
# 55602             วัฒนา     กรุงเทพมหานคร                       วาลเด้น อโศก
# 55613          บางละมุง            ชลบุรี                ซีซี คอนโดมิเนียม 2
# 55615           ราชเทวี     กรุงเทพมหานคร                 ไอดีโอ โมบิ รางน้ำ
# 55623            จอมทอง     กรุงเทพมหานคร     แกรนด์ คอนโดมิเนียม วุฒากาศ 57
#
#                              ชื่อโครงการ  \
# 9      เพอร์เฟค มาสเตอร์พีซ รัตนาธิเบศร์
# 13      พนาสนธิ์ การ์เด้นท์ วิลล์ ภูเก็ต
# 14                       เพลินวิว ทิวเขา
# 14                       เพลินวิว ทิวเขา
# 14                       เพลินวิว ทิวเขา
# ...                                  ...
# 55598      เดอะ ไพรเวซี่ พาร์ค รามอินทรา
# 55602                       วาลเด้น อโศก
# 55613                ซีซี คอนโดมิเนียม 2
# 55615                 ไอดีโอ โมบิ รางน้ำ
# 55623     แกรนด์ คอนโดมิเนียม วุฒากาศ 57
#
#                                           ผู้พัฒนา            ย่าน  \
# 9      บริษัท พร็อพเพอร์ตี้ เพอร์เฟค จำกัด (มหาชน)          ท่าอิฐ
# 13                     บริษัท พนาสนธิ์ กรุ๊ป จำกัด             NaN
# 14                  บริษัท ไลฟ แอนด์ ลีฟวิ่ง จำกัด        เก้ากิโล
# 14                  บริษัท ไลฟ แอนด์ ลีฟวิ่ง จำกัด        เก้ากิโล
# 14                  บริษัท ไลฟ แอนด์ ลีฟวิ่ง จำกัด        เก้ากิโล
# ...                                            ...             ...
# 55598       บริษัท พฤกษา เรียลเอสเตท จำกัด (มหาชน)  วัดไตรรัตนาราม
# 55602                   บริษัท ฮาบิแทท กรุ๊ป จำกัด            อโศก
# 55613             บริษัท รวมโชคพัฒนา (พัทยา) จำกัด     บุญสัมพันธ์
# 55615   บริษัท อนันดา ดีเวลลอปเม้นท์ จำกัด (มหาชน)          รางน้ำ
# 55623    บริษัท โมเดิร์น เฮาส์ พร็อพเพอร์ตี้ จำกัด          จอมทอง
#
#                ตำบล         อำเภอ        จังหวัด  data_source
# 9            ไทรม้า  เมืองนนทบุรี        นนทบุรี        house
# 13            วิชิต   เมืองภูเก็ต         ภูเก็ต        house
# 14        สุรศักดิ์       ศรีราชา         ชลบุรี        house
# 14        สุรศักดิ์       ศรีราชา         ชลบุรี        house
# 14        สุรศักดิ์       ศรีราชา         ชลบุรี        house
# ...             ...           ...            ...          ...
# 55598    อนุสาวรีย์        บางเขน  กรุงเทพมหานคร        condo
# 55602  คลองเตยเหนือ         วัฒนา  กรุงเทพมหานคร        condo
# 55613      หนองปรือ      บางละมุง         ชลบุรี        condo
# 55615      ถนนพญาไท       ราชเทวี  กรุงเทพมหานคร        condo
# 55623        บางค้อ        จอมทอง  กรุงเทพมหานคร        condo
#
# [48044 rows x 39 columns]
